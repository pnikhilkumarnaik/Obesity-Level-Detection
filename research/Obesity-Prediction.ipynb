# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Vs code\Obesity-Level-Detection\data\ObesityDataSet.csv")

# %%
df
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  \
# 0     21.000000  Female  1.620000   64.000000          no   no   2.0  3.0
# 1     21.000000  Female  1.520000   56.000000   Sometimes   no   3.0  3.0
# 2     23.000000    Male  1.800000   77.000000  Frequently   no   2.0  3.0
# 3     27.000000    Male  1.800000   87.000000  Frequently   no   3.0  3.0
# 4     22.000000    Male  1.780000   89.800000   Sometimes   no   2.0  1.0
# ...         ...     ...       ...         ...         ...  ...   ...  ...
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   float64
#  1   Gender                          2111 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  family_history_with_overweight  2111 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
df.isna().sum()
# Out:
# Age                               0
# Gender                            0
# Height                            0
# Weight                            0
# CALC                              0
# FAVC                              0
# FCVC                              0
# NCP                               0
# SCC                               0
# SMOKE                             0
# CH2O                              0
# family_history_with_overweight    0
# FAF                               0
# TUE                               0
# CAEC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2087, 17)

# %%
df.dtypes
# Out:
# Age                               float64
# Gender                             object
# Height                            float64
# Weight                            float64
# CALC                               object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# SCC                                object
# SMOKE                              object
# CH2O                              float64
# family_history_with_overweight     object
# FAF                               float64
# TUE                               float64
# CAEC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
numerical_cols = ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']
df[numerical_cols].hist(figsize=(12, 8), bins=20, color='skyblue', edgecolor='black')
plt.suptitle("Distribution of Numerical Features")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=df['Gender'], palette='coolwarm')
plt.title("Gender Distribution")
plt.show()
# Out:
# C:\Users\pnikh\AppData\Local\Temp\ipykernel_156456\1747571693.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Gender'], palette='coolwarm')

# %%
plt.figure(figsize=(12,5))
sns.countplot(y=df['NObeyesdad'], palette='viridis', order=df['NObeyesdad'].value_counts().index)
plt.title("Obesity Level Distribution")
plt.show()
# Out:
# C:\Users\pnikh\AppData\Local\Temp\ipykernel_156456\3855376458.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['NObeyesdad'], palette='viridis', order=df['NObeyesdad'].value_counts().index)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['CAEC'], hue=df['NObeyesdad'], palette='magma')
plt.title("Eating Habits vs Obesity Level")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=df['SMOKE'], palette='pastel')
plt.title("Smoking Habit Distribution")
plt.show()
# Out:
# C:\Users\pnikh\AppData\Local\Temp\ipykernel_156456\648267794.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['SMOKE'], palette='pastel')

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df['MTRANS'], palette='husl')
plt.title("Mode of Transportation Distribution")
plt.show()
# Out:
# C:\Users\pnikh\AppData\Local\Temp\ipykernel_156456\1444272322.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['MTRANS'], palette='husl')

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df['NObeyesdad'], y=df['FAF'], palette='coolwarm')
plt.title("Physical Activity vs Obesity")
plt.show()
# Out:
# C:\Users\pnikh\AppData\Local\Temp\ipykernel_156456\2587556792.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['NObeyesdad'], y=df['FAF'], palette='coolwarm')

# %%
df['NObeyesdad'].value_counts()
# Out:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_II    290
# Normal_Weight          282
# Overweight_Level_I     276
# Insufficient_Weight    267
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_col=[]
for i in df.columns:
    if df[i].dtype=='object':
        cat_col.append(i)
cat_col
# Out:
# ['Gender',
#  'CALC',
#  'FAVC',
#  'SCC',
#  'SMOKE',
#  'family_history_with_overweight',
#  'CAEC',
#  'MTRANS',
#  'NObeyesdad']

# %%
le=LabelEncoder()
for i in cat_col:
    df[i]=le.fit_transform(df[i])
df
# Out:
#             Age  Gender    Height      Weight  CALC  FAVC  FCVC  NCP  SCC  \
# 0     21.000000       0  1.620000   64.000000     3     0   2.0  3.0    0
# 1     21.000000       0  1.520000   56.000000     2     0   3.0  3.0    1
# 2     23.000000       1  1.800000   77.000000     1     0   2.0  3.0    0
# 3     27.000000       1  1.800000   87.000000     1     0   3.0  3.0    0
# 4     22.000000       1  1.780000   89.800000     2     0   2.0  1.0    0
# ...         ...     ...       ...         ...   ...   ...   ...  ...  ...
# 2106  20.976842       0  1.710730  131.408528     2     1   3.0  3.0    0
# 2107  21.982942       0  1.748584  133.742943     2     1   3.0  3.0    0
# 2108  22.524036       0  1.752206  133.689352     2     1   3.0  3.0    0
# 2109  24.361936       0  1.739450  133.346641     2     1   3.0  3.0    0
# 2110  23.664709       0  1.738836  133.472641     2     1   3.0  3.0    0
#
#       SMOKE      CH2O  family_history_with_overweight       FAF       TUE  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Height', 'Weight', 'CALC', 'FAVC', 'FCVC', 'NCP',
#        'SCC', 'SMOKE', 'CH2O', 'family_history_with_overweight', 'FAF', 'TUE',
#        'CAEC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
# !pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle

# %%
X = df.drop(columns=['NObeyesdad'])
y = df['NObeyesdad']
smote = SMOTE(sampling_strategy={0.0: 351, 1.0: 351, 2.0: 351, 3.0: 351, 4.0: 351, 5.0:351, 6.0:351})
X_resampled, y_resampled = smote.fit_resample(X, y)
df_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['NObeyesdad'])], axis=1)
df_resampled = shuffle(df_resampled, random_state=42).reset_index(drop=True)
df_resampled = df_resampled.sample(n=1000, random_state=42).reset_index(drop=True)
print(df_resampled['NObeyesdad'].value_counts())
print(f"Total records: {len(df_resampled)}")
# Out:
# NObeyesdad
# 0    158
# 2    157
# 4    143
# 3    138
# 1    136
# 5    135
# 6    133
# Name: count, dtype: int64
# Total records: 1000
# c:\Vs code\Obesity-Level-Detection\obesityEnv\Lib\site-packages\joblib\externals\loky\backend\context.py:131: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Vs code\Obesity-Level-Detection\obesityEnv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 247, in _count_physical_cores
#     cpu_count_physical = _count_physical_cores_win32()
#   File "c:\Vs code\Obesity-Level-Detection\obesityEnv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 299, in _count_physical_cores_win32
#     cpu_info = subprocess.run(
# ...

# %%
df['NObeyesdad'].value_counts()
# Out:
# NObeyesdad
# 2    351
# 4    324
# 3    297
# 6    290
# 1    282
# 5    276
# 0    267
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import *

# %%
# !pip install lightgbm
# !pip install xgboost

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import ExtraTreesClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import time

# %%
X=df.drop(columns=['NObeyesdad'])
Y=df['NObeyesdad']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,stratify=Y,random_state=26)

# %%
len(x_train),len(x_test)
# Out:
# (1460, 627)

# %%
lr1=LogisticRegression()
start_time=time.time()
lr1.fit(x_train,y_train)
end_time=time.time()
lrt=end_time-start_time
lr1_pred=lr1.predict(x_test)
print("Accuracy of Logistic Regression:",accuracy_score(lr1_pred,y_test))
print(classification_report(lr1_pred,y_test))
# Out:
# Accuracy of Logistic Regression: 0.6236044657097288
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86        82
#            1       0.60      0.58      0.59        88
#            2       0.34      0.43      0.38        84
#            3       0.73      0.76      0.74        86
#            4       0.99      0.72      0.83       133
#            5       0.47      0.50      0.48        78
#            6       0.39      0.45      0.42        76
#
#     accuracy                           0.62       627
#    macro avg       0.63      0.61      0.62       627
# weighted avg       0.66      0.62      0.64       627
# c:\Vs code\Obesity-Level-Detection\obesityEnv\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# ...

# %%
dt1=DecisionTreeClassifier()
start_time=time.time()
dt1.fit(x_train,y_train)
end_time=time.time()
dtt=end_time-start_time
dt1_pred=dt1.predict(x_test)
print("Accuracy of Decision Tree:",accuracy_score(dt1_pred,y_test))
print(classification_report(dt1_pred,y_test))
# Out:
# Accuracy of Decision Tree: 0.9330143540669856
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96        83
#            1       0.79      0.89      0.84        75
#            2       0.95      0.98      0.97       103
#            3       0.97      0.97      0.97        89
#            4       1.00      0.99      0.99        98
#            5       0.90      0.81      0.85        93
#            6       0.93      0.94      0.94        86
#
#     accuracy                           0.93       627
#    macro avg       0.93      0.93      0.93       627
# weighted avg       0.94      0.93      0.93       627

# %%
rf1=RandomForestClassifier(n_estimators=500)
start_time=time.time()
rf1.fit(x_train,y_train)
end_time=time.time()
rft=end_time-start_time
rf1_pred=rf1.predict(x_test)
print("Accuracy of Random Forest:",accuracy_score(rf1_pred,y_test))
print(classification_report(rf1_pred,y_test))
# Out:
# Accuracy of Random Forest: 0.9473684210526315
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        78
#            1       0.92      0.83      0.87        94
#            2       0.95      0.99      0.97       102
#            3       0.98      1.00      0.99        87
#            4       1.00      0.99      0.99        98
#            5       0.90      0.91      0.91        82
#            6       0.92      0.93      0.92        86
#
#     accuracy                           0.95       627
#    macro avg       0.95      0.95      0.95       627
# weighted avg       0.95      0.95      0.95       627

# %%
KNN1=KNeighborsClassifier()
start_time=time.time()
KNN1.fit(x_train,y_train)
end_time=time.time()
KNNt=end_time-start_time
KNN1_pred=KNN1.predict(x_test)
print("Accuracy of KNN:",accuracy_score(KNN1_pred,y_test))
print(classification_report(KNN1_pred,y_test))
# Out:
# Accuracy of KNN: 0.8803827751196173
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91        90
#            1       0.61      0.79      0.69        66
#            2       0.92      0.88      0.90       110
#            3       0.96      0.93      0.94        91
#            4       0.98      0.97      0.97        98
#            5       0.88      0.83      0.85        88
#            6       0.84      0.87      0.85        84
#
#     accuracy                           0.88       627
#    macro avg       0.88      0.88      0.87       627
# weighted avg       0.89      0.88      0.88       627

# %%
GNB1=GaussianNB()
start_time=time.time()
GNB1.fit(x_train,y_train)
end_time=time.time()
GNBt=end_time-start_time
GNB1_pred=GNB1.predict(x_test)
print("Accuracy of GNB:",accuracy_score(GNB1_pred,y_test))
print(classification_report(GNB1_pred,y_test))
# Out:
# Accuracy of GNB: 0.543859649122807
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72        81
#            1       0.38      0.70      0.49        46
#            2       0.00      0.00      0.00         0
#            3       0.71      0.78      0.74        81
#            4       0.99      0.98      0.98        98
#            5       0.19      0.64      0.30        25
#            6       0.87      0.26      0.40       296
#
#     accuracy                           0.54       627
#    macro avg       0.55      0.58      0.52       627
# weighted avg       0.79      0.54      0.58       627
# c:\Vs code\Obesity-Level-Detection\obesityEnv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
svm1=SVC()
start_time=time.time()
svm1.fit(x_train,y_train)
end_time=time.time()
svmt=end_time-start_time
svm1_pred=svm1.predict(x_test)
print("Accuracy of SVM:",accuracy_score(svm1_pred,y_test))
print(classification_report(svm1_pred,y_test))
# Out:
# Accuracy of SVM: 0.5869218500797448
#               precision    recall  f1-score   support
#
#            0       0.93      0.76      0.83        98
#            1       0.48      0.59      0.53        70
#            2       0.32      0.42      0.37        80
#            3       0.43      0.90      0.58        42
#            4       1.00      0.63      0.77       154
#            5       0.46      0.59      0.52        64
#            6       0.53      0.39      0.45       119
#
#     accuracy                           0.59       627
#    macro avg       0.59      0.61      0.58       627
# weighted avg       0.66      0.59      0.60       627

# %%
etc1=ExtraTreesClassifier()
start_time=time.time()
etc1.fit(x_train,y_train)
end_time=time.time()
etct=end_time-start_time
etc1_pred=etc1.predict(x_test)
print("Accuracy of ETC:",accuracy_score(etc1_pred,y_test))
print(classification_report(etc1_pred,y_test))
# Out:
# Accuracy of ETC: 0.9346092503987241
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96        79
#            1       0.87      0.80      0.84        92
#            2       0.96      0.96      0.96       106
#            3       0.98      1.00      0.99        87
#            4       0.99      1.00      0.99        96
#            5       0.90      0.88      0.89        85
#            6       0.87      0.93      0.90        82
#
#     accuracy                           0.93       627
#    macro avg       0.93      0.93      0.93       627
# weighted avg       0.93      0.93      0.93       627

# %%
lgbm1 = LGBMClassifier()
start_time=time.time()
lgbm1.fit(x_train,y_train)
end_time=time.time()
lgbt=end_time-start_time
lgbm1_pred=lgbm1.predict(x_test)
print("Accuracy of LGB:",accuracy_score(lgbm1_pred,y_test))
print(classification_report(lgbm1_pred,y_test))
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000666 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2061
# [LightGBM] [Info] Number of data points in the train set: 1460, number of used features: 16
# [LightGBM] [Info] Start training from score -2.055083
# [LightGBM] [Info] Start training from score -2.002988
# [LightGBM] [Info] Start training from score -1.784934
# [LightGBM] [Info] Start training from score -1.948654
# [LightGBM] [Info] Start training from score -1.861242
# [LightGBM] [Info] Start training from score -2.023502
# [LightGBM] [Info] Start training from score -1.972986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
xgb1 = XGBClassifier()
start_time=time.time()
xgb1.fit(x_train,y_train)
end_time=time.time()
xgbt=end_time-start_time
xgb1_pred=xgb1.predict(x_test)
print("Accuracy of LGB:",accuracy_score(xgb1_pred,y_test))
print(classification_report(xgb1_pred,y_test))
# Out:
# Accuracy of LGB: 0.9760765550239234
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        80
#            1       0.95      0.93      0.94        87
#            2       0.99      0.98      0.99       107
#            3       0.99      1.00      0.99        88
#            4       1.00      1.00      1.00        97
#            5       0.93      0.96      0.94        80
#            6       0.98      0.97      0.97        88
#
#     accuracy                           0.98       627
#    macro avg       0.97      0.98      0.98       627
# weighted avg       0.98      0.98      0.98       627

# %%
results_df={"Algorithm":['Logistic Regression',"SVM",'Decision Tree','Random Forest','KNN','GNB','ETC','LGB','XGB'],"Accuracy":[accuracy_score(lr1_pred,y_test),accuracy_score(svm1_pred,y_test),accuracy_score(dt1_pred,y_test),accuracy_score(rf1_pred,y_test),accuracy_score(KNN1_pred,y_test),accuracy_score(GNB1_pred,y_test),accuracy_score(etc1_pred,y_test),accuracy_score(lgbm1_pred,y_test),accuracy_score(xgb1_pred,y_test)],   
            #"Recall":[recall_score(lr1_pred,y_test),recall_score(svm1_pred,y_test),recall_score(dt1_pred,y_test),recall_score(rf1_pred,y_test),recall_score(KNN1_pred,y_test),recall_score(GNB1_pred,y_test),recall_score(etc1_pred,y_test)],
            #"Precision":[precision_score(lr1_pred,y_test),precision_score(svm1_pred,y_test),precision_score(dt1_pred,y_test),precision_score(rf1_pred,y_test),precision_score(KNN1_pred,y_test),precision_score(GNB1_pred,y_test),precision_score(etc1_pred,y_test)],
           #"F1-Score":[f1_score(lr1_pred,y_test),f1_score(svm1_pred,y_test),f1_score(dt1_pred,y_test),f1_score(rf1_pred,y_test),f1_score(KNN1_pred,y_test),f1_score(GNB1_pred,y_test),f1_score(etc1_pred,y_test)]
           }
results_df=pd.DataFrame(results_df)
results_df
# Out:
#              Algorithm  Accuracy
# 0  Logistic Regression  0.623604
# 1                  SVM  0.586922
# 2        Decision Tree  0.933014
# 3        Random Forest  0.947368
# 4                  KNN  0.880383
# 5                  GNB  0.543860
# 6                  ETC  0.934609
# 7                  LGB  0.980861
# 8                  XGB  0.976077

# %%
plt.figure(figsize=(25,3))
plt.subplot(1,2,1)
plt.title("Accuracies of algorithms")
plt.xticks(rotation=45)
sns.lineplot(data=results_df,x=results_df['Algorithm'],y=results_df['Accuracy'])
# Out:
# <Axes: title={'center': 'Accuracies of algorithms'}, xlabel='Algorithm', ylabel='Accuracy'>

# %%
ax=results_df.set_index('Algorithm').plot(kind='bar', figsize=(13, 6))

plt.ylabel('Scores')
plt.title('Algorithm Performance Metrics')

for p in ax.patches:
    ax.annotate(f'{p.get_height():.3f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', rotation=90)
    
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.heatmap(confusion_matrix(lr1_pred,y_test),annot=True,cmap='Blues')
plt.title("Confusion Matrix of Logistic Regression")

plt.subplot(1,3,2)
sns.heatmap(confusion_matrix(dt1_pred,y_test),annot=True,cmap='Greens')
plt.title("Confusion Matrix of Decision Tree")

plt.subplot(1,3,3)
sns.heatmap(confusion_matrix(rf1_pred,y_test),annot=True,cmap='Oranges')
plt.title("Confusion Matrix of Random Forest")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix of Random Forest')

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.heatmap(confusion_matrix(svm1_pred,y_test),annot=True,cmap='bone')
plt.title("Confusion Matrix of SVM")

plt.subplot(1,3,2)
sns.heatmap(confusion_matrix(KNN1_pred,y_test),annot=True,cmap='summer')
plt.title("Confusion Matrix of KNN")

plt.subplot(1,3,3)
sns.heatmap(confusion_matrix(GNB1_pred,y_test),annot=True,cmap='gist_heat')
plt.title("Confusion Matrix of Gaussian Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix of Gaussian Naive Bayes')

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.heatmap(confusion_matrix(etc1_pred,y_test),annot=True,cmap='gist_heat')
plt.title("Confusion Matrix of Extra Trees Classifier")

plt.subplot(1,3,2)
sns.heatmap(confusion_matrix(lgbm1_pred,y_test),annot=True,cmap='summer')
plt.title("Confusion Matrix of LGB")

plt.subplot(1,3,3)
sns.heatmap(confusion_matrix(xgb1_pred,y_test),annot=True,cmap='gist_heat')
plt.title("Confusion Matrix of XGBoost")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix of XGBoost')

# %%
time_df={"Algorithm":['Logistic Regression',"SVM",'Decision Tree','Random Forest','KNN','GNB','ETC','LGB','XGB'],
         "Execution Time in Seconds":[lrt,svmt,dtt,rft,KNNt,GNBt,etct,lgbt,xgbt]}
time_df=pd.DataFrame(time_df)
time_df
# Out:
#              Algorithm  Execution Time in Seconds
# 0  Logistic Regression                   0.084037
# 1                  SVM                   0.030725
# 2        Decision Tree                   0.010374
# 3        Random Forest                   1.260368
# 4                  KNN                   0.002042
# 5                  GNB                   0.003164
# 6                  ETC                   0.144574
# 7                  LGB                   0.520004
# 8                  XGB                   0.265029

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=time_df,x=time_df['Algorithm'],y=time_df['Execution Time in Seconds'])
plt.xlabel("Algorithms")
plt.ylabel("Execution Time in Seconds")
plt.title("Time Taken For Model Training")
# Out:
# Text(0.5, 1.0, 'Time Taken For Model Training')

# %%
from joblib import dump
dump(lgbm1, 'lgbm1.joblib')
print("Model saved as 'lgbm11.joblib'")
dump(lgbm1,'lgbm1.pkl')
# Out:
# Model saved as 'lgbm11.joblib'
# ['lgbm1.pkl']

# %%
from joblib import load
rf1=load("lgbm1.joblib")

# %%
def preprocess_and_test(rf1,random_record_number):
    testing =pd.read_csv(r"C:\Vs code\Obesity-Level-Detection\data\ObesityDataSet.csv")
    le=LabelEncoder()
    for i in cat_col:
        testing[i]=le.fit_transform(testing[i])
    testing=pd.DataFrame(testing.iloc[random_record_number]).T
    class_value = testing['NObeyesdad'].iloc[0]
    print("Actual Value is",end=' ')
    if class_value == 0.0:
        print("Insufficient_Weight")
    elif class_value == 1.0:
        print("Normal_Weight")
    elif class_value == 2.0:
        print("Obesity_Type_I")
    elif class_value == 3.0:
        print("Obesity_Type_II")
    elif class_value == 4.0:
        print("Obesity_Type_III")
    elif class_value == 5.0:
        print("Overweight_Level_I")
    else:
        print("Overweight_Level_II")
    testing.drop(columns=['NObeyesdad'],inplace=True)
    
    print("Predicted is ",end='')
    if lgbm1.predict(testing) == 0.0:
        print("Insufficient_Weight")
    elif lgbm1.predict(testing) == 1.0:
        print("Normal_Weight")
    elif lgbm1.predict(testing) == 2.0:
        print("Obesity_Type_I")
    elif lgbm1.predict(testing) == 3.0:
        print("Obesity_Type_II")
    elif lgbm1.predict(testing) == 4.0:
        print("Obesity_Type_III")
    elif lgbm1.predict(testing) == 5.0:
        print("Overweight_Level_I")
    else:
        print("Overweight_Level_II") 

preprocess_and_test(rf1,75)
# Out:
# Actual Value is Insufficient_Weight
# Predicted is Insufficient_Weight
